# %% [markdown]
# # Twitter Act Report

# %% [markdown]
# ## Author:
# ### Victor Mayowa, ADELEYE (MB;BS), Google Certified Data Analyst and Udacity Scholar

# %% [markdown]
# ## Table of Contents
# <ul>
# <li><a href="#preface">Preface</a></li>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#insight">Insights</a></li>
# <li><a href="#visualizing">Data Visualizations</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='preface'></a>
#
# ## Preface
# > This project is my second project as a student of ALX-Udacity Data Analytics Nanodegree scholarship programme, which is a project intensive and career-focused training programme. It is instituted to provide and hone the skills of budding data analysts.
# > There are two reports requested:
# >> - Twitter Wrangling Report
# >> - Twitter Act Report

# %% [markdown]
# <a id='intro'></a>
#
# ## Introduction
# >
# > This report is to script out certain insights gotten from the the wrangled  data and communicate it via visualization

# %% [markdown]
# <a id='insight'></a>
#
# ## Insights
#
# 1. There is 78% positive correlation between number of tweets retweeted and liked. This suggest that there is a strong connection between a loiked and retweeted tweet such that a tweet with a lot of likes will most likely have a lot of retweets
#
# 2. Pupper was found to be the most used among the nicknames given to dogs. Although, large percentage of the tweets did not indicate nicknames.
#
# 3. golden_retriever and Labrador_retriever are the most predicted breed from the image posted
#
# 4. Most of the tweets came from Iphone users

# %% [markdown]
# <a id='visualizing'></a>
#
# ## Data Visualizations

# %% [markdown]
# #### INSIGHT 1
#
# > - There is a strong relationship between the number of retweets and favourites of tweeest. About 78% was revelaed. this shows that a liked tweets will most likely be retweeted.
# > - below is the visualization to show the correlation

# %% [markdown]
# ![favret.png](attachment:favret.png)

# %% [markdown]
# #### INSIGHT 2
# >
# > - Among the connotations used to describe the dogs tweeted, pupper comes to be the commonest mentioned among tweeters, folowed by doggo. However, it must be noted that most of the observations gotten has no nickname
# > - below is the visualization that shows the top 5 most common connotations used to describe dogs tweeted

# %% [markdown]
# ![Nickname.jpg](attachment:Nickname.jpg)

# %% [markdown]
# #### INSIGHT
# >
# > - It was found out that the most common source where tweets were posted came from Iphone users(98% of them)
# > - below is piechart representing the source of tweets.

# %% [markdown]
# ![pie1.png](attachment:pie1.png)

# %% [markdown]
# <a id='conclusions'></a>
#
# ## Conclusions
#
# - More investigation can be done to know the reason a breed is preferable or should we conclude these breeds are the most preferable among dog buyers.
# - Is there a bias that should be investigated since majority of tweets came from Iphone users?
# - This analysis can be used by dog merchants to know the breeds of dogs at the least popular among Iphone users

# %% [markdown]
# # THANK YOU
